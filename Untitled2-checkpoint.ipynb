# %%
from sklearn.datasets import load_iris
iris=load_iris()
#print (iris['data'])
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(iris['data'],iris['target'],random_state=0)

# %%
% matplotlib notebook
print(X_train.shape)
import matplotlib.pyplot as plt
fig,ax=plt.subplots(3,3, figsize=(15,15))
#plt.supertitle("iris_pairplot")

for i in range(3):
    for j in range(3):
        ax[i,j].scatter(X_train[:,j],X_train[:,i+1],c=y_train,s=10)
        ax[i,j].set_xticks(())
        ax[i,j].set_yticks(())
        if(i==2):ax[i,j].set_xlabel(iris['feature_names'][j])
        if(j==0):ax[i,j].set_ylabel(iris['feature_names'][i+j])
        if(j>i):ax[i,j].set_visible(False)
# Out:
# (112, 4)
# <img src="data:image/png;base64,..." width="1500">

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
X_new=np.array[[5,2.9,1,0.2]]
prediction=knn.predict(X_new)
print(iris['target_names'][prediction])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-91bf4ff16827> in <module>()
#       3 knn=KNeighborsClassifier(n_neighbors=1)
#       4 knn.fit(X_train,y_train)
# ----> 5 X_new=np.array[[5,2.9,1,0.2]]
#       6 prediction=knn.predict(X_new)
#       7 print(iris['target_names'][prediction])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
